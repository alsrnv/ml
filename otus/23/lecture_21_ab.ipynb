# %% [markdown]
# <img src='otus.png'>

# %% [markdown]
# # A/B-тестирование

# %% [markdown]
# Рассмотрим несколько примеров пользовательского опыта.
#
# https://www.wordstream.com/blog/ws/2012/09/25/a-b-testing

# %% [markdown]
# #### 1. PPC ads - Pay per click ads. Варианты отображения рекламы.
#
# * A. Get \$10 off the first purchase. Book online now!
# * B. Get an additional \$10 off. Book online now.
#
# The CTR doubled with option … B.
# CTR - click-through rate.
# На рекламу из варианта B кликов больше.

# %% [markdown]
# #### 2. Выбор цвета и формы кнопки заказа
# <img src="button-ab-test.png">
#
# Использование второго варианта кнопки увеличило конверсию на 11%

# %% [markdown]
# https://www.widerfunnel.com/case-studies/babyage-com-e-commerce-retailer-lifts-sales-conversion-rate-by-22-with-conversion-rate-optimization/
#
# #### 3. Выбор компоновки элементов сайта
#
# 1. <img src="BabyAge_Control.jpg">
# 2. <img src="BabyAge_Variation.jpg">
#
# 2: Winning Test Page Variation – 22% higher sales conversion rate

# %% [markdown]
# Часто возникает необходимость принимать решения о реализации задачи, которое в дальнейшем повлияет на продукт. Так или иначе решение повлияет на прибыль.
#
# Какие решения мы принимаем?
#
# * цвет кнопки
# * порядок слов
# * расположение рекламного баннера
# * расположение блока рекомендаций
# * обязательность полей в форме регистрации
# * ...
# * ваши примеры?
#
# Нужен инструмент, позволяющий среди многих вариантов выбрать наиболее выгодное решение.
# Что это означает?
#
# Нельзя заранее сказать, какое решение будет более выгодным. Часто выгодный вариант не является ожидаемым. Каждый выбор должен быть обоснованным, нужно иметь возможность доказать, что решение будет наилучшим.

# %% [markdown]
# ## Концепция A/B-теста
#
# <img src="ab_test_3_kak_provoditsya_ab_testirovanie.jpg">
#
# * **Фиксируем** некоторую версию
# * Всех пользователей делим на **две (или несколько) группы**
# * Половина пользователей видит **старую** версию
# * Половина пользователей видит **новую** версию
# * Измеряем **метрику** в течение некоторого **периода**
# * **Анализируем** результат
# * Принимаем **решение**

# %% [markdown]
# ### Для чего нужен A/B-тест?
#
# Повторение всех этапов такого процесса позволяет постоянно проводить экперименты и достигать существенного увеличения прибыли в бизнесе.
#
# Пример - компания Барака Обамы 2008 года. Выбор между видео и изображением в пользу изображения позволил собрать дополнительные 57 млн долл. пожертвований.
#
# Наличие такого инструмента позволяет проводить сотни экспериментов и последовательно искать пути повышения прибыли.

# %% [markdown]
# ### Для чего A/B-тест в нашем курсе?
#
# Что еще можно протестировать?
#
# * Новый алгоритм ранжирования поисковой выдачи
# * Новый способ давать рекомендации (1, 2 или 5?)
# * Новый алгоритм рекомендации товаров
# * Новая модель, предсказывающая, кликнет ли пользователь на рекламу
# * Новая модель ...
# * Ваши варианты?
#
# Всегда нужно обосновывать, почему нужно внедрить новый алгоритм или новую модель. Лучше всего для этого работает хорошо оформленная презентация и достоверные числа на проведенном эксперименте.
# Если работа проделана, но не протестирована и не внедрена - работа не сделана

# %% [markdown]
# # Подготовительный этап

# %% [markdown]
# ## Критерии эффективности
#
# До начала тестирования нужно зафиксировать метрики или т.н. прокси-метрики.
#
# Метрики связаны с бизнесом напрямую - объем прибыли.
# Иногда их нельзя измерить напрямую, например количество пользователей, полностью прошедших полугодовую обучающую программу, но можно измерить косвенно, например количество пользователей, нажавших на кнопку регистрации на курс (повышение конверсии)

# %% [markdown]
# ## A/A-тестирование
#
# A/A тестирование - тестирование, в котором обе группы контрольные. Это позволяет провести эксперимент от начала и до конца и расчитать метрики без внедрения новой функциональности.
# Это надежный способ узнать о статистической значимости эксперимента и протестировать инфраструктуру эксперимента.
#
# Если в A/A видно различие в выборках, значит в постановке эксперимента есть существенные ошибки.
#
# * (+) мониторинг инфраструктуры
# * (+) мониторинг изменения метрики
# * (-) потеря денег (недополученная прибыль)
# * (+) возможность вычислить дисперсию выборки (понадобится для проверки гипотез)
# * (+) возможность попробовать тестирование на практике при первом внедрении без рисков

# %% [markdown]
# ## Планирование A/B-теста
#
# Все этапы эксперимента должны быть определены заранее.
#
# Список контрольных вопросов:
#
# **Цель**
# - в чем цель этого теста?
#
# **Зоны ответственности**
# - кто представитель от бизнеса?
# - кто отвечает за реализацию теста?
# - кто осуществляет аналитику?
#
# **Планирование эксперимента**
# - кто входит в тестовую и контрольную группы?
# - каковы нулевая и альтернативная гипотеза?
# - какие показатели планируется отслеживать?
# - когда начало тестирования?
# - с какого момента начинается эксперимент для аналитических целей (есть ли эффект новизны)?
# - сколько продлится тест?
# - каков размер выборки?
#
# **Процесс анализа**
# - кто будет проводить анализ?
# - какой вид анализа будет проводиться?
# - когда начнется процесс анализа?
# - когда завершится процесс анализа?
# - какое ПО будет использоваться для проведения анализа?
#
# **Результаты**
# - как будут распространяться результаты анализа?
# - как будет приниматься окончательное решение?

# %% [markdown]
# ## Размер выборки

# %% [markdown]
# # Проведение тестирования
#
# ## Выбор участников тестирования
#
# * определить критерии отбора участников тестирования
#
# Например, нужно протестировать функциональность только для пользователей сервиса женского пола. Или только для пользователей Москвы.
#
# * обеспечить стратификацию (соотношение пользователей разных типов)
#
# * определить соотношение пользователей в выборках
#
# Есть соблазн проводить тестирование на очень маленькой выборке пользователей. Тестирование нужно будет проводить дольше, чем если выборка будет большая. Это может быть сильно дороже.
#
# * определить механизм разделения пользователей
#   * учесть повторные заходы на сайт одного и того же пользователя
#   * учесть возможность неравномерного распределения идентификаторов. Например первая цифра в ID или остаток от деления хэша ID на 2
#
# * определить условия возможного эффекта новизны
#   * пользователь регулярно заходит на сайт и видит новый дизайн. В ужасе закрывает, на следующий день заходит снова. Можем увидеть резкое изменение характеристики из-за такого фактора.

# %% [markdown]
# ## Начало тестирования
#
# Пример схемы тестирования
# * 1% пользователей направляется в тестовую группу на 4 часа
# * 5% пользователей направляется в тестовую группу на 4 часа (дополнительные 4%)
# * 20% пользователей направляется в тестовую группу на 4 часа
# * 50% пользователей направляется в тестовую группу на оставшееся время тестирования
#
# Такой подход позволяет мониторить метрики и остановить тестирование в случае, если что-то идет не так

# %% [markdown]
# ## Завершение тестирования
#
# Отслеживать нужно размер выборки.
# **Нельзя останавливать тестирование, когда достигнут значимый результат**

# %% [markdown]
# ## Анализ результатов тестов
#
# <img src='ab_process.png'>
#
#
# Разберем пример. Пользователь кликает на кнопку.
# Рассмотрим тестирование цвета кнопки: синяя или красная.
#
# ### Биномиальное распределение
#
# Можно использовать, когда:
# * ровно два исхода
# * события независимы
# * все события из одного и того же распределения
#
# Рассмотрим факт клика на кнопку.
# Вероятность клика $p = 3/4$
#
# Клик - success, отсутствие клика - failure
#
# Событие - пользователь видит кнопку и кликает или не кликает.
#
# Фиксируем N - количество событий.
#
# При N = 10, какова вероятность получить 0, 1, 2, 3, ... 10 успехов?
#
# http://databits.io/bits/fbmx-binomial-distribution
#
# <img src='bin.png'>

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import numpy as np


n, p = 1000, 0.4

x = np.arange(binom.ppf(0.01, n, p), binom.ppf(0.99, n, p))
plt.plot(x, binom.pmf(x, n, p), 'bo', ms=8, label='binom pmf')
plt.vlines(x, 0, binom.pmf(x, n, p), colors='b', lw=5, alpha=0.5)
plt.show()

# %% [markdown]
# Вероятность клика можно оценить, посчитав количество кликов и поделив на количество показов

# %% [markdown]
# ### Постановка гипотез, SIMPLE 2-SAMPLE T-TEST (Двухвыборочный t-критерий для независимых выборок)
#
# **Нулевая гипотеза**
# Основное предположение об отсутствии разницы между сравниваемыми вариантами.
#
# Например:
# Предполагаем, что CTR в контрольной группе = CTR в тестируемой группе.
#
# **Альтернативная гипотеза**
# Предположение, к которому приходим, если опровергается нулевая гипотеза.
#
# Например:
# CTR в контрольной группе != CTR в тестируемой группе.
#
#
# Возвращаемся к кнопке.
# **Нулевая гипотеза**: значения CTR для синей кнопки и для красной кнопки одинаковы
# **Альтернативная гипотеза**: значения CTR для синей кнопки и для красной кнопки различаются
#
# Для обеих групп можем вычислить вероятность клика на кнопку. Получаем два биномиальных распределения. Нам нужно оценить совпадают они, или отличаются
#
#
# <img src='h1.png'>
# Картинка из статьи https://rexplorations.wordpress.com/2015/08/13/hypothesis-tests-2-sample-tests-ab-tests/

# %% [markdown]
# $$H_0: \hat{p}_{red} - \hat{p}_{blue} = 0$$
# $$H_1: \hat{p}_{red} - \hat{p}_{blue} \neq 0$$
#
# Вычислить: $$p(\hat{p}_{red} - \hat{p}_{blue} | H_0)$$
#
# Выберем уровень значимости 5% (похоже, что так сложилось исторически).
#
# Это означает, что мы отвергнем нулевую гипотезу при $$p(\hat{p}_{red} - \hat{p}_{blue} | H_0) < 0.05 = \alpha$$
#
# Наша цель понять, то, что распределения не совпали это случайность? Или то, что они не совпали не может быть случайностью (случайный исход маловероятен)
#
# Чтобы оценить два распределения, нужно знать стандартное отклонение - вторая характеристика нормального распределения. Нам она неизвестна. Поэтому пользуемся объединенным стандартным отклонением.
#
#
# $x_{red}, x_{blue}$ - количество пользователей, сделавших клик в каждой группе
#
# $n_{red}, n_{blue}$ - общее количество пользователей
#
# Объединенная вероятность клика:
# $$\hat{p}_{pool} = \frac{x_{red}+ x_{blue}}{n_{red}+ n_{blue}}$$
#
# Объединенное стандартное отклонение:
# $$ SE_{pool} = \sqrt{\hat{p}_{pool}\cdot(1-\hat{p}_{pool})\cdot(\frac{1}{n_{red}} + \frac{1}{n_{blue}})}$$
#
# Разность для гипотезы:
#
# $$\hat{d}=\hat{p}_{red} - \hat{p}_{blue}$$
#
# Гипотеза:
# $H_0: d = 0, \hat{d} \sim \mathcal{N}(0, SE_{pool})$
#
# Отклоним нулевую гипотезу если:
#
# $$\hat{d} > 1.96 \cdot SE_{pool}$$
#
# или
#
# $$\hat{d} < - 1.96 \cdot SE_{pool}$$

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.figure_factory import create_table
import plotly.offline as offline

offline.init_notebook_mode()

import numpy as np
import pandas as pd
import scipy


data1 = np.random.normal(0, 1, size=50)
data2 = np.random.normal(2, 1, size=50)


x = np.linspace(-4, 4, 160)
y1 = scipy.stats.norm.pdf(x)
y2 = scipy.stats.norm.pdf(x, loc=2)

trace1 = go.Scatter(
    x = x,
    y = y1,
    mode = 'lines+markers',
    name='Mean of 0'
)

trace2 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines+markers',
    name='Mean of 2'
)

data = [trace1, trace2]

offline.iplot(data, filename='normal-dists-plot')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <div id="63481a60-1cc8-4f0b-bda6-ff63e87ef512" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("63481a60-1cc8-4f0b-bda6-ff63e87ef512", [{"mode": "lines+markers", "name": "Mean of 0", "x": [-4.0, -3.949685534591195, -3.89937106918239, -3.849056603773585, -3.79874213836478, -3.748427672955975, -3.69811320754717, -3.647798742138365, -3.59748427672956, -3.547169811320755, -3.49685534591195, -3.4465408805031448, -3.3962264150943398, -3.3459119496855347, -3.2955974842767297, -3.2452830188679247, -3.1949685534591197, -3.1446540880503147, -3.0943396226415096, -3.0440251572327046, -2.9937106918238996, -2.9433962264150946, -2.8930817610062896, -2.8427672955974845, -2.792452830188679, -2.742138364779874, -2.691823899371069, -2.641509433962264, -2.591194968553459, -2.540880503144654, -2.490566037735849, -2.440251572327044, -2.389937106918239, -2.339622641509434, -2.289308176100629, -2.238993710691824, -2.188679245283019, -2.138364779874214, -2.088050314465409, -2.0377358490566038, -1.9874213836477987, -1.9371069182389937, -1.8867924528301887, -1.8364779874213837, -1.7861635220125787, -1.7358490566037736, -1.6855345911949686, -1.6352201257861636, -1.5849056603773581, -1.5345911949685531, -1.484276729559748, -1.433962264150943, -1.383647798742138, -1.333333333333333, -1.283018867924528, -1.232704402515723, -1.182389937106918, -1.132075471698113, -1.081761006289308, -1.031446540880503, -0.9811320754716979, -0.9308176100628929, -0.8805031446540879, -0.8301886792452828, -0.7798742138364778, -0.7295597484276728, -0.6792452830188678, -0.6289308176100628, -0.5786163522012577, -0.5283018867924527, -0.4779874213836477, -0.4276729559748427, -0.37735849056603765, -0.32704402515723263, -0.2767295597484276, -0.2264150943396226, -0.17610062893081757, -0.12578616352201255, -0.07547169811320753, -0.02515723270440251, 0.02515723270440251, 0.07547169811320753, 0.12578616352201255, 0.17610062893081757, 0.2264150943396226, 0.2767295597484276, 0.32704402515723263, 0.37735849056603765, 0.4276729559748427, 0.4779874213836477, 0.5283018867924527, 0.5786163522012577, 0.6289308176100628, 0.6792452830188678, 0.7295597484276728, 0.7798742138364778, 0.8301886792452837, 0.8805031446540887, 0.9308176100628938, 0.9811320754716988, 1.0314465408805038, 1.0817610062893088, 1.1320754716981138, 1.1823899371069189, 1.2327044025157239, 1.283018867924529, 1.333333333333334, 1.383647798742139, 1.433962264150944, 1.484276729559749, 1.534591194968554, 1.584905660377359, 1.635220125786164, 1.685534591194969, 1.735849056603774, 1.786163522012579, 1.8364779874213841, 1.8867924528301891, 1.9371069182389942, 1.9874213836477992, 2.037735849056604, 2.0880503144654092, 2.1383647798742142, 2.1886792452830193, 2.2389937106918243, 2.2893081761006293, 2.3396226415094343, 2.3899371069182394, 2.4402515723270444, 2.4905660377358494, 2.5408805031446544, 2.5911949685534594, 2.6415094339622645, 2.6918238993710695, 2.7421383647798745, 2.7924528301886795, 2.8427672955974845, 2.8930817610062896, 2.9433962264150946, 2.9937106918238996, 3.0440251572327046, 3.0943396226415096, 3.1446540880503147, 3.1949685534591197, 3.2452830188679247, 3.2955974842767297, 3.3459119496855347, 3.3962264150943398, 3.4465408805031448, 3.49685534591195, 3.547169811320755, 3.59748427672956, 3.647798742138365, 3.69811320754717, 3.748427672955975, 3.79874213836478, 3.849056603773585, 3.89937106918239, 3.949685534591195, 4.0], "y": [0.00013383022576488537, 0.0001634593137296936, 0.00019914329822608222, 0.00024200385486718937, 0.0002933455037104626, 0.0003546803690648505, 0.0004277553315391216, 0.0005145816256802114, 0.0006174669001697036, 0.0007390497131960796, 0.0008823363827568234, 0.0010507400498488142, 0.0012481217415208792, 0.0014788331405350208, 0.0017477606791031317, 0.002060370476311189, 0.0024227535332166763, 0.0028416704873759305, 0.003 ...

# %%
twosample_results = scipy.stats.ttest_ind(data1, data2)

matrix_twosample = [
    ['', 'Test Statistic', 'p-value'],
    ['Sample Data', twosample_results[0], twosample_results[1]]
]

twosample_table = create_table(matrix_twosample, index=True)
offline.iplot(twosample_table, filename='twosample-table')
# Out:
# <div id="680bfeee-7b97-4493-a491-607a8ef0462a" style="height: 110px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("680bfeee-7b97-4493-a491-607a8ef0462a", [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "showscale": false, "z": [[0, 0, 0], [0, 0.5, 0.5]], "type": "heatmap", "uid": "f7ec38e7-fce6-4b5b-8dfb-eda49079d80e"}], {"annotations": [{"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b></b>", "x": -0.45, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>Test Statistic</b>", "x": 0.55, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>p-value</b>", "x": 1.55, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>Sample Data</b>", "x": -0.45, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}, {"align": "left", "font": {"color": "#000000"}, "showarrow": false, "text": "-10.0934999186", "x": 0.55, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}, {"align": "left", "font": {"color": "#000000"}, "showarrow": false, "text": "7.5856197835e-17", "x": 1.55, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}], "height": 110, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "xaxis": {"dtick": 1, "gridwidth": 2, "showticklabels": false, "tick0": -0.5, "ticks": "", "zeroline": false}, "yaxis": {"autorange": "reversed", "dtick": 1, "gridwidth": 2, "showticklabels": false, "tick0": 0.5, "ticks": "", "zeroline": false}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("680bfeee-7b97-4493-a491-607a8ef0462a"));});</script>

# %%
data1 = np.random.normal(0, 1, size=50)
data2 = np.random.normal(0, 1, size=50)


x = np.linspace(-4, 4, 160)
y1 = scipy.stats.norm.pdf(x)
y2 = scipy.stats.norm.pdf(x)

trace1 = go.Scatter(
    x = x,
    y = y1,
    mode = 'lines+markers',
    name='Mean of 0'
)

trace2 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines+markers',
    name='Mean of 2'
)

data = [trace1, trace2]

offline.iplot(data, filename='normal-dists-plot')
# Out:
# <div id="cb478b72-befd-403a-83a5-b786813aefb2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cb478b72-befd-403a-83a5-b786813aefb2", [{"mode": "lines+markers", "name": "Mean of 0", "x": [-4.0, -3.949685534591195, -3.89937106918239, -3.849056603773585, -3.79874213836478, -3.748427672955975, -3.69811320754717, -3.647798742138365, -3.59748427672956, -3.547169811320755, -3.49685534591195, -3.4465408805031448, -3.3962264150943398, -3.3459119496855347, -3.2955974842767297, -3.2452830188679247, -3.1949685534591197, -3.1446540880503147, -3.0943396226415096, -3.0440251572327046, -2.9937106918238996, -2.9433962264150946, -2.8930817610062896, -2.8427672955974845, -2.792452830188679, -2.742138364779874, -2.691823899371069, -2.641509433962264, -2.591194968553459, -2.540880503144654, -2.490566037735849, -2.440251572327044, -2.389937106918239, -2.339622641509434, -2.289308176100629, -2.238993710691824, -2.188679245283019, -2.138364779874214, -2.088050314465409, -2.0377358490566038, -1.9874213836477987, -1.9371069182389937, -1.8867924528301887, -1.8364779874213837, -1.7861635220125787, -1.7358490566037736, -1.6855345911949686, -1.6352201257861636, -1.5849056603773581, -1.5345911949685531, -1.484276729559748, -1.433962264150943, -1.383647798742138, -1.333333333333333, -1.283018867924528, -1.232704402515723, -1.182389937106918, -1.132075471698113, -1.081761006289308, -1.031446540880503, -0.9811320754716979, -0.9308176100628929, -0.8805031446540879, -0.8301886792452828, -0.7798742138364778, -0.7295597484276728, -0.6792452830188678, -0.6289308176100628, -0.5786163522012577, -0.5283018867924527, -0.4779874213836477, -0.4276729559748427, -0.37735849056603765, -0.32704402515723263, -0.2767295597484276, -0.2264150943396226, -0.17610062893081757, -0.12578616352201255, -0.07547169811320753, -0.02515723270440251, 0.02515723270440251, 0.07547169811320753, 0.12578616352201255, 0.17610062893081757, 0.2264150943396226, 0.2767295597484276, 0.32704402515723263, 0.37735849056603765, 0.4276729559748427, 0.4779874213836477, 0.5283018867924527, 0.5786163522012577, 0.6289308176100628, 0.6792452830188678, 0.7295597484276728, 0.7798742138364778, 0.8301886792452837, 0.8805031446540887, 0.9308176100628938, 0.9811320754716988, 1.0314465408805038, 1.0817610062893088, 1.1320754716981138, 1.1823899371069189, 1.2327044025157239, 1.283018867924529, 1.333333333333334, 1.383647798742139, 1.433962264150944, 1.484276729559749, 1.534591194968554, 1.584905660377359, 1.635220125786164, 1.685534591194969, 1.735849056603774, 1.786163522012579, 1.8364779874213841, 1.8867924528301891, 1.9371069182389942, 1.9874213836477992, 2.037735849056604, 2.0880503144654092, 2.1383647798742142, 2.1886792452830193, 2.2389937106918243, 2.2893081761006293, 2.3396226415094343, 2.3899371069182394, 2.4402515723270444, 2.4905660377358494, 2.5408805031446544, 2.5911949685534594, 2.6415094339622645, 2.6918238993710695, 2.7421383647798745, 2.7924528301886795, 2.8427672955974845, 2.8930817610062896, 2.9433962264150946, 2.9937106918238996, 3.0440251572327046, 3.0943396226415096, 3.1446540880503147, 3.1949685534591197, 3.2452830188679247, 3.2955974842767297, 3.3459119496855347, 3.3962264150943398, 3.4465408805031448, 3.49685534591195, 3.547169811320755, 3.59748427672956, 3.647798742138365, 3.69811320754717, 3.748427672955975, 3.79874213836478, 3.849056603773585, 3.89937106918239, 3.949685534591195, 4.0], "y": [0.00013383022576488537, 0.0001634593137296936, 0.00019914329822608222, 0.00024200385486718937, 0.0002933455037104626, 0.0003546803690648505, 0.0004277553315391216, 0.0005145816256802114, 0.0006174669001697036, 0.0007390497131960796, 0.0008823363827568234, 0.0010507400498488142, 0.0012481217415208792, 0.0014788331405350208, 0.0017477606791031317, 0.002060370476311189, 0.0024227535332166763, 0.0028416704873759305, 0.003 ...

# %%
twosample_results = scipy.stats.ttest_ind(data1, data2)

matrix_twosample = [
    ['', 'Test Statistic', 'p-value'],
    ['Sample Data', twosample_results[0], twosample_results[1]]
]

twosample_table = create_table(matrix_twosample, index=True)
offline.iplot(twosample_table, filename='twosample-table')
# Out:
# <div id="c04b3451-3552-4d95-9f87-f069876ad709" style="height: 110px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c04b3451-3552-4d95-9f87-f069876ad709", [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "showscale": false, "z": [[0, 0, 0], [0, 0.5, 0.5]], "type": "heatmap", "uid": "b272385c-1153-44c7-bbc4-bcc563d2df6b"}], {"annotations": [{"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b></b>", "x": -0.45, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>Test Statistic</b>", "x": 0.55, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>p-value</b>", "x": 1.55, "xanchor": "left", "xref": "x", "y": 0, "yref": "y"}, {"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>Sample Data</b>", "x": -0.45, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}, {"align": "left", "font": {"color": "#000000"}, "showarrow": false, "text": "-10.0934999186", "x": 0.55, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}, {"align": "left", "font": {"color": "#000000"}, "showarrow": false, "text": "7.5856197835e-17", "x": 1.55, "xanchor": "left", "xref": "x", "y": 1, "yref": "y"}], "height": 110, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "xaxis": {"dtick": 1, "gridwidth": 2, "showticklabels": false, "tick0": -0.5, "ticks": "", "zeroline": false}, "yaxis": {"autorange": "reversed", "dtick": 1, "gridwidth": 2, "showticklabels": false, "tick0": 0.5, "ticks": "", "zeroline": false}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c04b3451-3552-4d95-9f87-f069876ad709"));});</script>

# %% [markdown]
# # Пример расчета
#
# Рассмотрим две независимые выборки и проверим гипотезу.

# %%
import numpy as np
g1 = np.array([4, 4, 3, 2, 5, 1, 1, 4])
g2 = np.array([3, 7, 8, 5, 4, 7, 6, 8])

m1 = g1.mean()
m2 = g2.mean()

ss1 = np.sum((g1 - m1) ** 2)
ss2 = np.sum((g2 - m2) ** 2)

print('m1 = {}'.format(m1))
print('m2 = {}'.format(m2))

print('ss1 = {}'.format(ss1))
print('ss2 = {}'.format(ss2))
# Out:
# m1 = 3.0
# m2 = 6.0
# ss1 = 16.0
# ss2 = 24.0

# %% [markdown]
# #### Шаг 1. Сформулировать гипотезы, выбрать уровень значимости
#
# $H_0: \mu_1 - \mu_2 = 0$
# $H_1: \mu_1 - \mu_2 \neq 0$
#
# Уровень значимости установим в
# $ \alpha = 0.05 $
#
# #### Шаг 2. Установить critical region
#
# Количество степеней свободы:

# %%
df1 = len(g1) - 1
df2 = len(g2) - 1
df = df1 + df2

print('df = {}'.format(df))
# Out:
# df = 14

# %% [markdown]
# Из таблицы t распределения получаем, что для $ \alpha = 0.05 $ и $df = 14$
#
# critical t-values:
#
# $2.145, –2.145$
#
# #### Шаг 3. Вычислить t статистику
#
# Pooled variance (объединенная дисперсия):

# %%
s_p_squared = (ss1 + ss2) * 1. / (df1 + df2)
print('s_p_squared = {}'.format(s_p_squared))
# Out:
# s_p_squared = 2.857142857142857

# %% [markdown]
# Оценка стандартного отклонения

# %%
s_m1_m2 = np.sqrt(s_p_squared / len(g1) + s_p_squared / len(g2))
print('s_m1_m2 = {}'.format(s_m1_m2))
# Out:
# s_m1_m2 = 0.8451542547285166

# %% [markdown]
# t статистика:

# %%
t = ((m1 - m2) - 0) / s_m1_m2
print('t = {}'.format(t))
# Out:
# t = -3.5496478698597698

# %% [markdown]
# #### Шаг 4. Принятие решения
#
# Полученная t статистика попадает в критический регион левого хвоста (t = +-2.145). Это означает, что нулевая гипотеза отвергается

# %%
import scipy.stats
twosample_results = scipy.stats.ttest_ind(g1, g2)
twosample_results
# Out:
# Ttest_indResult(statistic=-3.5496478698597698, pvalue=0.0032031662883185946)

# %% [markdown]
# ### Планирование размера выборки
#
# Необходимо зафиксировать результат, который для бизнеса будет статистически значим.
# Например, при росте CTR на 2% мы точно внедрим новый алгоритм.
#
# http://www.evanmiller.org/ab-testing/sample-size.html

# %% [markdown]
# # Другие подходы
#
# ## Многовариантное тестирование
#
# Применяется, когда необходимо протестировать большое количество вариантов.
# См. многовариантное тестирование, дробный факторный эксперимент, дисперсионный анализ, ANOVA

# %% [markdown]
# ## Байесовские бандиты
#
# Концепция.
# Есть агент. Его окружение неизвестно.
# Ему доступно несколько вариантов действий.
# Каждое действие может принести, а может и не принести некоторую награду. У каждого действия свое распределение параметров возможных наград.
# Нужно выбрать такую стратегию, чтобы заработать как можно больше наград.
#
# <img src="band.png">

# %% [markdown]
# 1. Карл Андерсон. Аналитическая культура. Глава 8 A/B-тестирование
# Всю книгу есть смысл прочесть для понимания некоторых концептуальных нюансов анализа данных в компаниях.
# 1. Frederick J Gravetter, Larry B. Wallnau. Essentials of Statistics for the Behavioral Sciences. Глава 10
# Книга по статистике для начинающих.
# 1. http://www.evanmiller.org/ab-testing/sample-size.html
# калькулятор для расчета размера выборки для А/Б-теста
# 1. http://gopractice.ru/
# блог по продуктовой аналитике
# 2. https://classroom.udacity.com/courses/ud257/
# курс о A/B тестировании от Google
# 1. https://www.wordstream.com/blog/ws/2012/09/25/a-b-testing
# статья "24 of the Most Surprising A/B Tests of All Time@"
# 1. http://www.evanmiller.org/how-not-to-run-an-ab-test.html
# статья "How Not To Run an A/B Test"
